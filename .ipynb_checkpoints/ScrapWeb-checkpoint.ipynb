# %%
pip install requests
pip install lxml

# %%
import requests
import lxml.html

class Games:
    def __init__ (self,titles,prices,totalTags,totalPlatforms):
        self.titles = titles
        self.prices = prices
        self.totalTags = totalTags
        self.totalPlatforms = totalPlatforms

html = requests.get ("https://store.steampowered.com/explore/new/")

doc = lxml.html.fromstring(html.content)

newReleases = doc.xpath('//div[@id="tab_newreleases_content"]')[0]

#print(newReleases)

titles = newReleases.xpath('.//div[@class="tab_item_name"]/text()')

#print(titles)

prices = newReleases.xpath('.//div[@class="discount_final_price"]/text()')

#print(prices)

tags = newReleases.xpath('.//div[@class="tab_item_top_tags"]')

totalTags = []

for tag in tags:
    totalTags.append(tag.text_content())

#print(totalTags)

totalTags = [tag.split(', ') for tag in totalTags]

#print(totalTags)

platformsdiv = newReleases.xpath('.//div[@class="tab_item_details"]')

totalPlatforms = []

for game in platformsdiv:
    namePlatform = game.xpath('.//span[contains(@class, "platform_img")]')
    platforms=[t.get('class').split(' ')[-1] for t in namePlatform]
    if 'had_separator' in platforms:
        platforms.remove('had_separator')
    totalPlatforms.append(platforms)

#print(totalPlatforms)

output = []

for info in zip(titles,prices,totalTags,totalPlatforms):
    response = {}
    response['title'] = info[0]
    response['price'] = info[1]
    response['tags'] = info[2]
    response['platforms'] = info[3]
    output.append(response)

#print(output)

for juego  in zip(titles,prices,totalTags,totalPlatforms):
    juegos = Games(juego[0],juego[1],juego[2],juego[3])
    print("Title: " + juegos.titles)
    print("Price: " + juegos.prices)
    print("Tags: " + str(juegos.totalTags))
    print("Platforms: " + str(juegos.totalPlatforms))
# Out:
# Title: MarZ: Tactical Base Defense
# Price: Mex$ 197.99
# Tags: ['Strategy', 'Indie', 'Tower Defense', 'Gore']
# Platforms: ['win']
# Title: ISLANDERS
# Price: Mex$ 61.19
# Tags: ['Indie', 'Strategy', 'City Builder', 'Building']
# Platforms: ['win']
# Title: Photographs
# Price: Mex$ 107.19
# Tags: ['Indie', 'Adventure', 'Casual', 'Pixel Graphics']
# Platforms: ['win']
# Title: Lovers of Aether
# Price: Free
# Tags: ['Psychological Horror', 'Casual', 'Indie', 'Simulation']
# Platforms: ['win', 'mac']
# Title: Tropico 6
# Price: Mex$ 454.99
# Tags: ['Strategy', 'City Builder', 'Simulation', 'Economy']
# Platforms: ['win', 'linux']
# Title: Unheard
# Price: Mex$ 114.00
# Tags: ['Detective', 'Indie', 'RPG', 'Mystery']
# Platforms: ['win']
# Title: Warparty
# Price: Mex$ 233.99
# Tags: ['Strategy', 'RTS', 'Base Building', 'Real-Time']
# Platforms: ['win', 'mac']
# Title: Outward
# Price: Mex$ 769.00
# Tags: ['RPG', 'Open World', 'Survival', 'Co-op']
# Platforms: ['win']
# Title: Out of the Park Baseball 20
# Price: Mex$ 367.99
# Tags: ['Simulation', 'Sports', 'Indie', 'Strategy']
# Platforms: ['win', 'mac', 'linux']
# Title: Out of the Park Baseball 20
# Price: Mex$ 367.99
# Tags: ['Simulation', 'Sports', 'Indie', 'Strategy']
# Platforms: ['win', 'mac', 'linux']
# Title: Sekiro™: Shadows Die Twice
# Price: Mex$ 1,299.00
# Tags: ['Action', 'Souls-like', 'Difficult', 'Singleplayer']
# Platforms: ['win']
# Title: Fate/EXTELLA LINK
# Price: Mex$ 454.99
# Tags: ['Action', 'Anime', 'Hack and Slash', 'Multiplayer']
# Platforms: ['win']
# Title: Baba Is You
# Price: Mex$ 154.99
# Tags: ['Indie', 'Puzzle', 'Difficult', 'Pixel Graphics']
# Platforms: ['win', 'mac', 'linux']
# Title: Devil May Cry 5
# Price: Mex$ 1,300.00
# Tags: ['Action', 'Hack and Slash', 'Great Soundtrack', 'Character Action Game']
# Platforms: ['win']
# Title: Production Line : Car factory simulation
# Price: Mex$ 233.99
# Tags: ['Management', 'Simulation', 'Strategy', 'Economy']
# Platforms: ['win']
# Title: When the Darkness comes
# Price: Free
# Tags: ['Free to Play', 'Psychological Horror', 'Indie', 'Adventure']
# Platforms: ['win']
# Title: Dawn of Man
# Price: Mex$ 233.99
# Tags: ['City Builder', 'Strategy', 'Simulation', 'Survival']
# Platforms: ['win', 'mac']
# Title: Space Engineers
# Price: Mex$ 185.99
# Tags: ['Space', 'Sandbox', 'Building', 'Multiplayer']
# Platforms: ['win']
# Title: Space Engineers
# Price: Mex$ 185.99
# Tags: ['Space', 'Sandbox', 'Building', 'Multiplayer']
# Platforms: ['win']
# Title: Pacify
# Price: Mex$ 57.99
# Tags: ['Horror', 'Multiplayer', 'Co-op', 'Action']
# Platforms: ['win', 'mac']
# Title: War of Omens Card Game
# Price: Free To Play
# Tags: ['Free to Play', 'Strategy', 'Indie', 'Card Game']
# Platforms: ['win', 'mac']
# Title: Far Cry® New Dawn
# Price: Mex$ 799.00
# Tags: ['Open World', 'Action', 'FPS', 'Multiplayer']
# Platforms: ['win']
# Title: Enderal: Forgotten Stories
# Price: Free
# Tags: ['Adventure', 'RPG', 'Story Rich', 'Open World']
# Platforms: ['win']
# Title: Sid Meier's Civilization® VI: Gathering Storm
# Price: Mex$ 599.00
# Tags: ['Strategy', 'Turn-Based', '4X', 'Turn-Based Strategy']
# Platforms: ['win', 'mac', 'linux']
# Title: GOD EATER 3
# Price: Mex$ 1,249.00
# Tags: ['Action', 'Anime', 'Character Customization', 'Co-op']
# Platforms: ['win']
# Title: ASTRONEER
# Price: Mex$ 279.99
# Tags: ['Open World', 'Survival', 'Multiplayer', 'Space']
# Platforms: ['win']
# Title: RESIDENT EVIL 2 / BIOHAZARD RE:2
# Price: Mex$ 1,299.00
# Tags: ['Zombies', 'Survival Horror', 'Horror', 'Gore']
# Platforms: ['win']
# Title: Battlefleet Gothic: Armada 2
# Price: Mex$ 559.99
# Tags: ['Strategy', 'Space', 'Warhammer 40K', 'Real Time Tactics']
# Platforms: ['win']
# Title: Slay the Spire
# Price: Mex$ 233.99
# Tags: ['Card Game', 'Turn-Based', 'Rogue-like', 'Strategy']
# Platforms: ['win', 'mac', 'linux']
# Title: My Time At Portia
# Price: Mex$ 329.99
# Tags: ['Open World', 'Crafting', 'RPG', 'Simulation']
# Platforms: ['win']
# Title: Insurgency: Sandstorm
# Price: Mex$ 349.90
# Tags: ['FPS', 'Realistic', 'Shooter', 'Multiplayer']
# Platforms: ['win']
# Title: DUSK
# Price: Mex$ 179.99
# Tags: ['FPS', 'Action', 'Horror', 'Retro']
# Platforms: ['win', 'mac', 'linux']
# Title: Kenshi
# Price: Mex$ 279.99
# Tags: ['Open World', 'Sandbox', 'RPG', 'Survival']
# Platforms: ['win']
# Title: Mutant Year Zero: Road to Eden
# Price: Mex$ 429.99
# Tags: ['Strategy', 'RPG', 'Adventure', 'Turn-Based Combat']
# Platforms: ['win']
# Title: Prime World: Defenders 2
# Price: Free To Play
# Tags: ['Free to Play', 'Tower Defense', 'Strategy', 'Massively Multiplayer']
# Platforms: ['win']

# %%
import requests
import lxml.html
